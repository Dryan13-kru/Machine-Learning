# %% [markdown]
# <a href="https://colab.research.google.com/github/Dryan13-kru/Machine-Learning/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BAB 1 Mengumpulkan Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import missingno

from sklearn.model_selection import train_test_split

from sklearn.decomposition import PCA

from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import confusion_matrix

# %%
pd.set_option('display.max_columns', None) #melihat semua kolom

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/BIG DATA/K04_bank_customers.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Mengambil dataset
dataset = pd.read_csv('/content/drive/MyDrive/BIG DATA/K04_bank_customers.csv')

# %%
dataset
# Out:
#       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0      58;"management";"married";"tertiary";"no";2143...
# 1      44;"technician";"single";"secondary";"no";29;"...
# 2      33;"entrepreneur";"married";"secondary";"no";2...
# 3      47;"blue-collar";"married";"unknown";"no";1506...
# 4      33;"unknown";"single";"unknown";"no";1;"no";"n...
# ...                                                  ...
# 45206  51;"technician";"married";"tertiary";"no";825;...
# 45207  71;"retired";"divorced";"primary";"no";1729;"n...
# 45208  72;"retired";"married";"secondary";"no";5715;"...
# 45209  57;"blue-collar";"married";"secondary";"no";66...
# 45210  37;"entrepreneur";"married";"secondary";"no";2...
#
# [45211 rows x 1 columns]

# %%
dataset = pd.read_csv('/content/drive/MyDrive/BIG DATA/K04_bank_customers.csv', header=None)

# %%
dataset #data sudah sesuai
# Out:
#                                                        0
# 0      age;"job";"marital";"education";"default";"bal...
# 1      58;"management";"married";"tertiary";"no";2143...
# 2      44;"technician";"single";"secondary";"no";29;"...
# 3      33;"entrepreneur";"married";"secondary";"no";2...
# 4      47;"blue-collar";"married";"unknown";"no";1506...
# ...                                                  ...
# 45207  51;"technician";"married";"tertiary";"no";825;...
# 45208  71;"retired";"divorced";"primary";"no";1729;"n...
# 45209  72;"retired";"married";"secondary";"no";5715;"...
# 45210  57;"blue-collar";"married";"secondary";"no";66...
# 45211  37;"entrepreneur";"married";"secondary";"no";2...
#
# [45212 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

#Dengan asumsi 'data' adalah DataFrame Anda
for col in ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

# Print kolom
print(data['age'], data['job'], data['marital'], data['education'], data['default'], data['balance'], data['housing'], data['loan'], data['contact'], data['day'], data['month'], data['duration'], data['campaign'], data['pdays'], data['previous'], data['poutcome'], data['y'])
# Out:
# 0        40
# 1        26
# 2        15
# 3        29
# 4        15
#          ..
# 45206    33
# 45207    53
# 45208    54
# 45209    39
# 45210    19
# Name: age, Length: 45211, dtype: int64 0         4
# 1         9
# 2         2
# 3         1
# 4        11
#          ..
# 45206     9
# 45207     5
# 45208     5
# 45209     1
# 45210     2
# Name: job, Length: 45211, dtype: int64 0        1
# 1        2
# 2        1
# 3        1
# 4        2
#         ..
# 45206    1
# 45207    0
# 45208    1
# 45209    1
# 45210    1
# Name: marital, Length: 45211, dtype: int64 0        2
# 1        1
# 2        1
# 3        3
# 4        3
#         ..
# 45206    2
# 45207    0
# 45208    1
# 45209    1
# 45210    1
# Name: education, Length: 45211, dtype: int64 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45206    0
# 45207    0
# 45208    0
# 45209    0
# 45210    0
# Name: default, Length: 45211, dtype: int64 0        3036
# 1         945
# 2         918
# ...

# %%
dataset.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# BAB 2 MENELAAH DATA

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
categorical_col = []
for column in dataset.columns:
    if dataset[column].dtype == object and len(dataset[column].unique()) <= 50: #mengecek level/isi data kolom (bisa object, int, dan tipe data lainnya)
        categorical_col.append(column)
        print(f"{column} : {dataset[column].unique()}")
        print("====================================")
# Out:
# job : ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# ...
# marital : ['married' 'single' 'divorced']
# ...
# education : ['tertiary' 'secondary' 'unknown' 'primary']
# ...
# default : ['no' 'yes']
# ...
# housing : ['yes' 'no']
# ...
# loan : ['no' 'yes']
# ...
# contact : ['unknown' 'cellular' 'telephone']
# ...
# month : ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# ...
# poutcome : ['unknown' 'failure' 'other' 'success']
# ...
# y : ['no' 'yes']
# ...

# %%
print(dataset.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
dataset['y'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
sns.set(font_scale=1.4)
dataset['y'].value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("Status Nasabah", labelpad=14)
plt.ylabel("Jumlah", labelpad=14)
plt.title("Status Nasabah", y=1.02);

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['age'],order=dataset['age'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (35,5))
sns.countplot(x=dataset['job'],order=dataset['job'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['marital'],order=dataset['marital'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['education'],order=dataset['education'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['default'],order=dataset['default'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['balance'],order=dataset['balance'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['housing'],order=dataset['housing'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['loan'],order=dataset['loan'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['contact'],order=dataset['contact'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['day'],order=dataset['day'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['month'],order=dataset['month'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['duration'],order=dataset['duration'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['campaign'],order=dataset['campaign'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['pdays'],order=dataset['pdays'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['previous'],order=dataset['previous'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['poutcome'],order=dataset['poutcome'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x=dataset['y'],order=dataset['y'].value_counts().index,hue=dataset['y'])
plt.show()

# %%
# Correlation Heatmap
correlation = dataset.corr()
plt.subplots(figsize = (9,9))
sns.heatmap(correlation.round(2),
            annot = True,
            vmax = 1,
            square = True,
            cmap = 'RdYlGn_r')
plt.show()
# Out:
# <ipython-input-54-d16bc9c96ddd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = dataset.corr()
